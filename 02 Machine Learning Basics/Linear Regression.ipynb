# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.20.0

# %%
# Other imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !wget https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/moore.csv
# Out:
# --2026-05-02 05:36:52--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/tf2.0/moore.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2302 (2.2K) [text/plain]
# Saving to: ‘moore.csv’
#
# moore.csv           100%[===================>]   2.25K  --.-KB/s    in 0s
#
# 2026-05-02 05:36:52 (36.1 MB/s) - ‘moore.csv’ saved [2302/2302]

# %%
# Load in the data
data = pd.read_csv('moore.csv', header=None).values
X = data[:,0].reshape(-1, 1) # make it a 2-D array of size N x D where D = 1
Y = data[:,1]

# %%
# Plot the data - it is exponential!
plt.scatter(X, Y)

# %%
# Since we want a linear model, let's take the log
Y = np.log(Y)
plt.scatter(X, Y)
# that's better

# %%
# Let's also center the X data so the values are not too large
# We could scale it too but then we'd have to reverse the transformation later
X = X - X.mean()

# %%
# Now create our Tensorflow model
model = tf.keras.models.Sequential([
  tf.keras.layers.Input(shape=(1,)),
  tf.keras.layers.Dense(1)
])

model.compile(optimizer=tf.keras.optimizers.SGD(0.001, 0.9), loss='mse')
# model.compile(optimizer='adam', loss='mse')


# learning rate scheduler
def schedule(epoch, lr):
  if epoch >= 50:
    return 0.0001
  return 0.001


scheduler = tf.keras.callbacks.LearningRateScheduler(schedule)


# Train the model
r = model.fit(X, Y, epochs=200, callbacks=[scheduler])
# Out:
# Epoch 1/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 396.9521 - learning_rate: 0.0010
# Epoch 2/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 290.5554 - learning_rate: 0.0010
# Epoch 3/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 248.1872 - learning_rate: 0.0010
# Epoch 4/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 209.9734 - learning_rate: 0.0010
# Epoch 5/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 190.4007 - learning_rate: 0.0010
# Epoch 6/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 146.6715 - learning_rate: 0.0010
# Epoch 7/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 114.4202 - learning_rate: 0.0010
# Epoch 8/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 100.7379 - learning_rate: 0.0010
# Epoch 9/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 75.3690 - learning_rate: 0.0010
# Epoch 10/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 52.7430 - learning_rate: 0.0010
# Epoch 11/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 30.7410 - learning_rate: 0.0010
# Epoch 12/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 22.0967 - learning_rate: 0.0010
# Epoch 13/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 16.8211 - learning_rate: 0.0010
# Epoch 14/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 12.7299 - learning_rate: 0.0010
# Epoch 15/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 8.7436 - learning_rate: 0.0010
# Epoch 16/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 6.3966 - learning_rate: 0.0010
# Epoch 17/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 5.3288 - learning_rate: 0.0010
# Epoch 18/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 3.9031 - learning_rate: 0.0010
# Epoch 19/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 2.8143 - learning_rate: 0.0010
# Epoch 20/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.4689 - learning_rate: 0.0010
# Epoch 21/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8435 - learning_rate: 0.0010
# Epoch 22/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9889 - learning_rate: 0.0010
# Epoch 23/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.8053 - learning_rate: 0.0010
# Epoch 24/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5065 - learning_rate: 0.0010
# Epoch 25/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6762 - learning_rate: 0.0010
# Epoch 26/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.7925 - learning_rate: 0.0010
# Epoch 27/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6494 - learning_rate: 0.0010
# Epoch 28/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4600 - learning_rate: 0.0010
# Epoch 29/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2378 - learning_rate: 0.0010
# Epoch 30/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9614 - learning_rate: 0.0010
# Epoch 31/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4203 - learning_rate: 0.0010
# Epoch 32/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0152 - learning_rate: 0.0010
# Epoch 33/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9477 - learning_rate: 0.0010
# Epoch 34/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9310 - learning_rate: 0.0010
# Epoch 35/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9143 - learning_rate: 0.0010
# Epoch 36/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8787 - learning_rate: 0.0010
# Epoch 37/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9683 - learning_rate: 0.0010
# Epoch 38/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8857 - learning_rate: 0.0010
# Epoch 39/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8763 - learning_rate: 0.0010
# Epoch 40/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9067 - learning_rate: 0.0010
# Epoch 41/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8853 - learning_rate: 0.0010
# Epoch 42/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8848 - learning_rate: 0.0010
# Epoch 43/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9133 - learning_rate: 0.0010
# Epoch 44/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9315 - learning_rate: 0.0010
# Epoch 45/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8865 - learning_rate: 0.0010
# Epoch 46/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8789 - learning_rate: 0.0010
# Epoch 47/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0929 - learning_rate: 0.0010
# Epoch 48/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1780 - learning_rate: 0.0010
# Epoch 49/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0103 - learning_rate: 0.0010
# Epoch 50/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9999 - learning_rate: 0.0010
# Epoch 51/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.9913 - learning_rate: 1.0000e-04
# Epoch 52/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8657 - learning_rate: 1.0000e-04
# Epoch 53/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8915 - learning_rate: 1.0000e-04
# Epoch 54/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9216 - learning_rate: 1.0000e-04
# Epoch 55/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9280 - learning_rate: 1.0000e-04
# Epoch 56/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8889 - learning_rate: 1.0000e-04
# Epoch 57/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8732 - learning_rate: 1.0000e-04
# Epoch 58/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8735 - learning_rate: 1.0000e-04
# Epoch 59/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8749 - learning_rate: 1.0000e-04
# Epoch 60/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8843 - learning_rate: 1.0000e-04
# Epoch 61/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8790 - learning_rate: 1.0000e-04
# Epoch 62/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8736 - learning_rate: 1.0000e-04
# Epoch 63/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9069 - learning_rate: 1.0000e-04
# Epoch 64/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8847 - learning_rate: 1.0000e-04
# Epoch 65/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8751 - learning_rate: 1.0000e-04
# Epoch 66/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8729 - learning_rate: 1.0000e-04
# Epoch 67/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8778 - learning_rate: 1.0000e-04
# Epoch 68/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8763 - learning_rate: 1.0000e-04
# Epoch 69/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8797 - learning_rate: 1.0000e-04
# Epoch 70/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9061 - learning_rate: 1.0000e-04
# Epoch 71/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8745 - learning_rate: 1.0000e-04
# Epoch 72/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9710 - learning_rate: 1.0000e-04
# Epoch 73/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8973 - learning_rate: 1.0000e-04
# Epoch 74/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8887 - learning_rate: 1.0000e-04
# Epoch 75/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8961 - learning_rate: 1.0000e-04
# Epoch 76/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8773 - learning_rate: 1.0000e-04
# Epoch 77/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8716 - learning_rate: 1.0000e-04
# Epoch 78/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8721 - learning_rate: 1.0000e-04
# Epoch 79/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8714 - learning_rate: 1.0000e-04
# Epoch 80/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8784 - learning_rate: 1.0000e-04
# Epoch 81/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8707 - learning_rate: 1.0000e-04
# Epoch 82/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8850 - learning_rate: 1.0000e-04
# Epoch 83/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9017 - learning_rate: 1.0000e-04
# Epoch 84/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8908 - learning_rate: 1.0000e-04
# Epoch 85/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8782 - learning_rate: 1.0000e-04
# Epoch 86/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8808 - learning_rate: 1.0000e-04
# Epoch 87/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8715 - learning_rate: 1.0000e-04
# Epoch 88/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8715 - learning_rate: 1.0000e-04
# Epoch 89/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8813 - learning_rate: 1.0000e-04
# Epoch 90/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8786 - learning_rate: 1.0000e-04
# Epoch 91/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8731 - learning_rate: 1.0000e-04
# Epoch 92/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8716 - learning_rate: 1.0000e-04
# Epoch 93/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8742 - learning_rate: 1.0000e-04
# Epoch 94/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8669 - learning_rate: 1.0000e-04
# Epoch 95/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8942 - learning_rate: 1.0000e-04
# Epoch 96/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8729 - learning_rate: 1.0000e-04
# Epoch 97/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8856 - learning_rate: 1.0000e-04
# Epoch 98/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8925 - learning_rate: 1.0000e-04
# Epoch 99/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9035 - learning_rate: 1.0000e-04
# Epoch 100/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9209 - learning_rate: 1.0000e-04
# Epoch 101/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8782 - learning_rate: 1.0000e-04
# Epoch 102/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8919 - learning_rate: 1.0000e-04
# Epoch 103/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9052 - learning_rate: 1.0000e-04
# Epoch 104/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8747 - learning_rate: 1.0000e-04
# Epoch 105/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8900 - learning_rate: 1.0000e-04
# Epoch 106/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8877 - learning_rate: 1.0000e-04
# Epoch 107/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8797 - learning_rate: 1.0000e-04
# Epoch 108/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8711 - learning_rate: 1.0000e-04
# Epoch 109/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8757 - learning_rate: 1.0000e-04
# Epoch 110/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8790 - learning_rate: 1.0000e-04
# Epoch 111/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8753 - learning_rate: 1.0000e-04
# Epoch 112/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8715 - learning_rate: 1.0000e-04
# Epoch 113/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8789 - learning_rate: 1.0000e-04
# Epoch 114/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8708 - learning_rate: 1.0000e-04
# Epoch 115/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8712 - learning_rate: 1.0000e-04
# Epoch 116/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8712 - learning_rate: 1.0000e-04
# Epoch 117/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8732 - learning_rate: 1.0000e-04
# Epoch 118/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8730 - learning_rate: 1.0000e-04
# Epoch 119/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8725 - learning_rate: 1.0000e-04
# Epoch 120/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8742 - learning_rate: 1.0000e-04
# Epoch 121/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8734 - learning_rate: 1.0000e-04
# Epoch 122/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9224 - learning_rate: 1.0000e-04
# Epoch 123/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0464 - learning_rate: 1.0000e-04
# Epoch 124/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9425 - learning_rate: 1.0000e-04
# Epoch 125/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8794 - learning_rate: 1.0000e-04
# Epoch 126/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8981 - learning_rate: 1.0000e-04
# Epoch 127/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8798 - learning_rate: 1.0000e-04
# Epoch 128/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8742 - learning_rate: 1.0000e-04
# Epoch 129/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8709 - learning_rate: 1.0000e-04
# Epoch 130/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8700 - learning_rate: 1.0000e-04
# Epoch 131/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8733 - learning_rate: 1.0000e-04
# Epoch 132/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8708 - learning_rate: 1.0000e-04
# Epoch 133/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8813 - learning_rate: 1.0000e-04
# Epoch 134/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8963 - learning_rate: 1.0000e-04
# Epoch 135/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8792 - learning_rate: 1.0000e-04
# Epoch 136/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8757 - learning_rate: 1.0000e-04
# Epoch 137/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8710 - learning_rate: 1.0000e-04
# Epoch 138/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8791 - learning_rate: 1.0000e-04
# Epoch 139/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8801 - learning_rate: 1.0000e-04
# Epoch 140/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8712 - learning_rate: 1.0000e-04
# Epoch 141/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8724 - learning_rate: 1.0000e-04
# Epoch 142/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8706 - learning_rate: 1.0000e-04
# Epoch 143/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8703 - learning_rate: 1.0000e-04
# Epoch 144/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8739 - learning_rate: 1.0000e-04
# Epoch 145/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8709 - learning_rate: 1.0000e-04
# Epoch 146/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9060 - learning_rate: 1.0000e-04
# Epoch 147/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8685 - learning_rate: 1.0000e-04
# Epoch 148/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9152 - learning_rate: 1.0000e-04
# Epoch 149/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9095 - learning_rate: 1.0000e-04
# Epoch 150/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8728 - learning_rate: 1.0000e-04
# Epoch 151/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8761 - learning_rate: 1.0000e-04
# Epoch 152/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8719 - learning_rate: 1.0000e-04
# Epoch 153/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8841 - learning_rate: 1.0000e-04
# Epoch 154/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8794 - learning_rate: 1.0000e-04
# Epoch 155/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8743 - learning_rate: 1.0000e-04
# Epoch 156/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8686 - learning_rate: 1.0000e-04
# Epoch 157/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8838 - learning_rate: 1.0000e-04
# Epoch 158/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8837 - learning_rate: 1.0000e-04
# Epoch 159/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8745 - learning_rate: 1.0000e-04
# Epoch 160/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8711 - learning_rate: 1.0000e-04
# Epoch 161/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8780 - learning_rate: 1.0000e-04
# Epoch 162/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8947 - learning_rate: 1.0000e-04
# Epoch 163/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8769 - learning_rate: 1.0000e-04
# Epoch 164/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8817 - learning_rate: 1.0000e-04
# Epoch 165/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8763 - learning_rate: 1.0000e-04
# Epoch 166/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8705 - learning_rate: 1.0000e-04
# Epoch 167/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8776 - learning_rate: 1.0000e-04
# Epoch 168/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8727 - learning_rate: 1.0000e-04
# Epoch 169/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8728 - learning_rate: 1.0000e-04
# Epoch 170/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8715 - learning_rate: 1.0000e-04
# Epoch 171/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8726 - learning_rate: 1.0000e-04
# Epoch 172/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.8697 - learning_rate: 1.0000e-04
# Epoch 173/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8727 - learning_rate: 1.0000e-04
# Epoch 174/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.8780 - learning_rate: 1.0000e-04
# Epoch 175/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8848 - learning_rate: 1.0000e-04
# Epoch 176/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8711 - learning_rate: 1.0000e-04
# Epoch 177/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.8709 - learning_rate: 1.0000e-04
# Epoch 178/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.8712 - learning_rate: 1.0000e-04
# Epoch 179/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8705 - learning_rate: 1.0000e-04
# Epoch 180/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8707 - learning_rate: 1.0000e-04
# Epoch 181/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8721 - learning_rate: 1.0000e-04
# Epoch 182/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8768 - learning_rate: 1.0000e-04
# Epoch 183/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8766 - learning_rate: 1.0000e-04
# Epoch 184/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8730 - learning_rate: 1.0000e-04
# Epoch 185/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8717 - learning_rate: 1.0000e-04
# Epoch 186/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8743 - learning_rate: 1.0000e-04
# Epoch 187/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8823 - learning_rate: 1.0000e-04
# Epoch 188/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8767 - learning_rate: 1.0000e-04
# Epoch 189/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.8732 - learning_rate: 1.0000e-04
# Epoch 190/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8727 - learning_rate: 1.0000e-04
# Epoch 191/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.8709 - learning_rate: 1.0000e-04
# Epoch 192/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8716 - learning_rate: 1.0000e-04
# Epoch 193/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8744 - learning_rate: 1.0000e-04
# Epoch 194/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8787 - learning_rate: 1.0000e-04
# Epoch 195/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8719 - learning_rate: 1.0000e-04
# Epoch 196/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9040 - learning_rate: 1.0000e-04
# Epoch 197/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.8901 - learning_rate: 1.0000e-04
# Epoch 198/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.8728 - learning_rate: 1.0000e-04
# Epoch 199/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8719 - learning_rate: 1.0000e-04
# Epoch 200/200
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.8710 - learning_rate: 1.0000e-04

# %%
# Plot the loss
plt.plot(r.history['loss'], label='loss')

# %%
# Get the slope of the line
# The slope of the line is related to the doubling rate of transistor count
print(model.layers) # Note: there is only 1 layer, the "Input" layer doesn't count
print(model.layers[0].get_weights())
# Out:
# [<Dense name=dense, built=True>]
# [array([[0.3422516]], dtype=float32), array([17.774725], dtype=float32)]

# %%
# The slope of the line is:
a = model.layers[0].get_weights()[0][0,0]

# %%
print("Time to double:", np.log(2) / a)
# Out:
# Time to double: 2.0252562235483667

# %%
# If you know the analytical solution
X = np.array(X).flatten()
Y = np.array(Y)
denominator = X.dot(X) - X.mean() * X.sum()
a = ( X.dot(Y) - Y.mean()*X.sum() ) / denominator
b = ( Y.mean() * X.dot(X) - X.mean() * X.dot(Y) ) / denominator
print(a, b)
print("Time to double:", np.log(2) / a)
# Out:
# 0.341682487387313 17.764939393631764
# Time to double: 2.0286295205239204

# %% [markdown]
# ## Part 2: Making Predictions

# %%
# Make sure the line fits our data
Yhat = model.predict(X).flatten()
plt.scatter(X, Y)
plt.plot(X, Yhat)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
# Manual calculation

# Get the weights
w, b = model.layers[0].get_weights()

# Reshape X because we flattened it again earlier
X = X.reshape(-1, 1)

# (N x 1) x (1 x 1) + (1) --> (N x 1)
Yhat2 = (X.dot(w) + b).flatten()

# Don't use == for floating points
np.allclose(Yhat, Yhat2)
# Out:
# True
